# %% [markdown]
# # Day 4: Introduction to Matplotlib and Data Visualization

# %% [markdown]
# # Matplotlib
#
# - low level graph plotting library in python that serves as a visualization utility.
#
# - open source and can be used freely.
#
# - mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.
#
# Code can be found here: https://github.com/matplotlib/matplotlib

# %% [markdown]
# ## installation

# %%
# !pip install matplotlib --upgrade
# Out:
# ...
#      ---------------------------------------- 7.6/7.6 MB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.0
#     Uninstalling matplotlib-3.7.0:
#       Successfully uninstalled matplotlib-3.7.0
# ...

# %% [markdown]
# ## importing matplotlib

# %%
import matplotlib

# %% [markdown]
# ## checking Matplotlib version

# %%
print(matplotlib.__version__)
# Out:
# 3.5.1

# %% [markdown]
# ## Matplotlib Pyplot

# %%
from matplotlib import pyplot as plt

# alternative:
import matplotlib.pyplot as plt

# %%
# import additional libaries to create toy data and do computations
import numpy as np

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Line plot

# %% [markdown]
# ### Draw a line in a diagram from position (0,0) to position (6,250)

# %%
# define x and y points (need to have the same dimensionality)
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

# %%
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ### Draw a line in a diagram from position (1, 3) to position (8, 10):

# %% [markdown]
# - by default, the plot() function draws a line from point to point
# - parameter 1 is an array containing the points on the x-axis
# - parameter 2 is an array containing the points on the y-axis

# %%
# define data
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

# plot
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Plotting without line

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

# define another 'marker'
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Multiple Points

# %%
# define x- and y-points
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

# plot
plt.plot(xpoints, ypoints)
plt.show()

# %%
# plot without line using a different marker
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Default X-points

# %% [markdown]
# - if we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 (etc., depending on the length of the y-points)

# %%
# define y-points
ypoints = np.array([3, 8, 1, 10, 5, 7])

# plot
plt.plot(ypoints)
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Markers

# %%
# define y-points
ypoints = np.array([3, 8, 1, 10])

# plot using specific markers
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints, marker = '*')

# %% [markdown]
# ### Marker references

# %% [markdown]
# Marker 	Description
#
# 'o'	 Circle
# '*'  Star
# '.'  Point
# ','  Pixel
# 'x'  X
# 'X'  X (filled)
# '+'  Plus
# 'P'  Plus (filled)
# 's'  Square
# 'D'  Diamond
# 'd'  Diamond (thin)
# 'p'  Pentagon
# 'H'  Hexagon
# 'h'  Hexagon
# 'v'  Triangle Down
# '^'  Triangle Up
# '<'  Triangle Left
# '>'  Triangle Right
# '1'  Tri Down
# '2'  Tri Up
# '3'  Tri Left
# '4'  Tri Right
# '|'  Vline
# '_'  Hline

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Format Strings: fmt

# %% [markdown]
# - use the shortcut string notation parameter to specify the marker:
#     marker | line | color

# %%
# define y-points
ypoints = np.array([3, 8, 1, 10])

# plot using fmt (o = marker; : = line style; r = color)
plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# ### Line references

# %% [markdown]
# Line Syntax 	Description
# '-'             Solid line
# ':'             Dotted line
# '--'            Dashed line
# '-.'            Dashed/dotted line

# %% [markdown]
# ### Color references

# %% [markdown]
# Color Syntax    Description
# 'r'             Red
# 'g'             Green
# 'b'             Blue
# 'c'             Cyan
# 'm'             Magenta
# 'y'             Yellow
# 'k'             Black
# 'w'             White

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Marker size

# %% [markdown]
# - use the keyword argument markersize or the shorter version, ms to set the size of the markers

# %%
# define y-points
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Marker color

# %% [markdown]
# - use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# - use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# - use both the mec and mfc arguments to color the entire marker

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# - use Hexadecimal color values
# - https://www.w3schools.com/colors/colors_hexadecimal.asp

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')

# %% [markdown]
# - use color names
# - https://www.w3schools.com/colors/colors_names.asp

# %%
 plt.plot(ypoints, marker = 'o', ms = 20, mec = 'darkred', mfc = 'coral')

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Linestyle

# %% [markdown]
# Line Syntax 	Description
# '-'             Solid line
# ':'             Dotted line
# '--'            Dashed line
# '-.'            Dashed/dotted line

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %% [markdown]
# ### shorter syntax

# %%
plt.plot(ypoints, linestyle = '--')
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Line color

# %% [markdown]
# - use the keyword argument color or the shorter c to set the color of the line

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# - use color names or hexadecimal color values

# %%
plt.plot(ypoints, c = '#4CAF50')

# %%
plt.plot(ypoints, c = 'forestgreen')

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Line Width

# %% [markdown]
# - use the keyword argument linewidth or the shorter lw to change the width of the line

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Multiple lines

# %% [markdown]
# - plot as many lines as you like by simply adding more plt.plot() functions

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# - plot many lines by adding the points for the x- and y-axis for each line in the same plt.plot() function

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Labels and Title

# %% [markdown]
# ### x- and y-labels

# %% [markdown]
# - use the xlabel() and ylabel() functions to set a label for the x- and y-axis

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

# define x- and y-labels
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ### Create a title

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ## Set font properties for title and labels

# %% [markdown]
# - use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Position of the title

# %% [markdown]
# - use the loc parameter in title() to position the title
# - values are: 'left', 'right', and 'center'; default value is 'center'

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Add grid lines

# %% [markdown]
# - use the grid() function to add grid lines to the plot

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# - use the axis parameter in the grid() function to specify which grid lines to display
# - values are: 'x', 'y', and 'both'; default value is 'both'

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %% [markdown]
# ## adjust line properties for the grid

# %% [markdown]
# - set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Figure Class

# %% [markdown]
# - top-level container for all plot elements

# %%
fig = plt.figure()

# %% [markdown]
# #### it has additional parameters:
# - figsize: ((width,height) tuple in inches)
# - dpi: (dots per inches)
# - facecolor: (figure patch facecolor)
# - edgecolor: (figure patch edge color)
# - linewidth: (Edge line width)

# %%
fig = plt.figure(figsize=(3,2),dpi=100,facecolor='w');
plt.plot();

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Axes class

# %% [markdown]
# - region of the image with the data space
# - given figure can contain many Axes, but a given Axes object can only be in one Figure
# - Axes object is added to figure by calling the add_axes() method
# - returns the axes object and adds an axes at position rect [left, bottom, width, height] where all quantities are in fractions of figure width and height

# %%
ax=fig.add_axes([0,0,1,1])

# %% [markdown]
# ### interlude: legends

# %%
# ax.legend(handles, labels, loc)

# %% [markdown]
# Location string 	Location code
# Best                0
# upper right         1
# upper left 	        2
# lower left 	        3
# lower right         4
# Right               5
# Center left         6
# Center right        7
# lower center        8
# upper center        9
# Center 	            10

# %% [markdown]
# ## example plot

# %%
y = [1, 4, 9, 16, 25,36,49, 64]
x1 = [1, 16, 30, 42,55, 68, 77,88]
x2 = [1,6,12,18,28, 40, 52, 65]
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
l1 = ax.plot(x1,y,'ys-') # solid line with yellow colour and square marker
l2 = ax.plot(x2,y,'go--') # dash line with green colour and circle marker
ax.legend(labels = ('tv', 'Smartphone'), loc = 'lower right') # legend placed at lower right
ax.set_title("Advertisement effect on sales")
ax.set_xlabel('medium')
ax.set_ylabel('sales')
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Working with multiple figures: Subplots and mosaic plots

# %% [markdown]
# - function returns a figure object and a tuple containing axes objects equal to nrows*ncols
# - each axes object is accessible by its index

# %%
fig, ax =  plt.subplots(nrows=2, ncols=2)

x = np.arange(1,5)
ax[0,0].plot(x,x*x)
ax[0,0].set_title('square')
ax[0,1].plot(x,np.sqrt(x))
ax[0,1].set_title('square root')
ax[1,0].plot(x,np.exp(x))
ax[1,0].set_title('exp')
ax[1,1].plot(x,np.log10(x))
ax[1,1].set_title('log')
plt.show()

# %% [markdown]
# ## Subplot: Mosaic

# %%
# Helper function used for visualization in the following examples
def identify_axes(ax_dict, fontsize=48):
    """
    Helper to identify the Axes in the examples below.

    Draws the label in a large font in the center of the Axes.

    Parameters
    ----------
    ax_dict : dict[str, Axes]
        Mapping between the title / label and the Axes.
    fontsize : int, optional
        How big the label should be.
    """
    kw = dict(ha="center", va="center", fontsize=fontsize, color="darkgrey")
    for k, ax in ax_dict.items():
        ax.text(0.5, 0.5, k, transform=ax.transAxes, **kw)

# %%
np.random.seed(19680801)
hist_data = np.random.randn(1_500)


fig = plt.figure(constrained_layout=True)
ax_array = fig.subplots(2, 2, squeeze=False)

ax_array[0, 0].bar(["a", "b", "c"], [5, 7, 9])
ax_array[0, 1].plot([1, 2, 3])
ax_array[1, 0].hist(hist_data, bins="auto")
ax_array[1, 1].imshow([[1, 2], [2, 1]])

identify_axes(
    {(j, k): a for j, r in enumerate(ax_array) for k, a in enumerate(r)},
)

# %% [markdown]
# - using Figure.subplot_mosaic we can produce the same mosaic but give the axes semantic names

# %%
fig = plt.figure(constrained_layout=True)
ax_dict = fig.subplot_mosaic(
    [
        ["bar", "plot"],
        ["hist", "image"],
    ],
)
ax_dict["bar"].bar(["a", "b", "c"], [5, 7, 9])
ax_dict["plot"].plot([1, 2, 3])
ax_dict["hist"].hist(hist_data)
ax_dict["image"].imshow([[1, 2], [2, 1]])
identify_axes(ax_dict)

# %% [markdown]
# - key difference between Figure.subplots and Figure.subplot_mosaic is the return value:
# - former returns an array for index access, the latter returns a dictionary mapping the labels to the axes.Axes instances created

# %%
mosaic = """
    AB
    CD
    """

# %% [markdown]
# - gives us 4 Axes laid out in a 2x2 grid and generates the same figure mosaic as above

# %%
fig = plt.figure(constrained_layout=True)
ax_dict = fig.subplot_mosaic(mosaic)
identify_axes(ax_dict)

# %% [markdown]
# ### Axes spanning multiple rows/columns

# %% [markdown]
# - something we can do with Figure.subplot_mosaic, that we cannot do with Figure.subplots, is to specify that an Axes should span several rows or columns

# %%
axd = plt.figure(constrained_layout=True).subplot_mosaic(
    """
    ABD
    CCD
    """
)
identify_axes(axd)

# %%
axd = plt.figure(constrained_layout=True).subplot_mosaic(
    """
    A.C
    BBB
    .D.
    """
)
identify_axes(axd)

# %% [markdown]
# - use another character (rather than a period ".") to mark the empty space, we can use empty_sentinel to specify the character to use

# %%
axd = plt.figure(constrained_layout=True).subplot_mosaic(
    """
    aX
    Xb
    """,
    empty_sentinel="X",
)
identify_axes(axd)

# %% [markdown]
# ### Controlling mosaic creation

# %% [markdown]
# - use the input to specify the arrangement, but set the relative widths of the rows / columns

# %%
mosaic = """AA
            BC"""
fig = plt.figure()
axd = fig.subplot_mosaic(
    mosaic,
    gridspec_kw={
        "bottom": 0.25,
        "top": 0.95,
        "left": 0.1,
        "right": 0.5,
        "wspace": 0.5,
        "hspace": 0.5,
    },
)
identify_axes(axd)

axd = fig.subplot_mosaic(
    mosaic,
    gridspec_kw={
        "bottom": 0.05,
        "top": 0.75,
        "left": 0.6,
        "right": 0.95,
        "wspace": 0.5,
        "hspace": 0.5,
    },
)
identify_axes(axd)

# %% [markdown]
# - we can also pass through arguments used to create the subplots (again, the same as Figure.subplots) which will apply to all of the Axes create

# %%
axd = plt.figure(constrained_layout=True).subplot_mosaic(
    "AB", subplot_kw={"projection": "polar"}
)
identify_axes(axd)

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Formatting Axes

# %% [markdown]
# - in some cases, the scale of an axis needs to be set as logarithmic rather than the normal scale
# - it is also required sometimes to show some additional distance between axis numbers and axis label
# - the labelpad property of either axis (x or y or both) can be set to the desired value

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,4))

x = np.arange(1,5)

ax[0].plot(x, np.exp(x))
ax[0].plot(x,x**2)
ax[0].set_title("Normal scale")

ax[1].plot (x, np.exp(x))
ax[1].plot(x, x**2)
ax[1].set_yscale("log")
ax[1].set_title("Logarithmic scale (y)")

ax[0].set_xlabel("x axis")
ax[0].set_ylabel("y axis")
ax[0].xaxis.labelpad = 10

ax[1].set_xlabel("x axis")
ax[1].set_ylabel("y axis")
plt.show()

# %% [markdown]
# - axis spines are the lines connecting axis tick marks demarcating boundaries of plot area
# - each spine can be formatted by specifying color and width
# - any edge can be made invisible if its color is set to non

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.spines['bottom'].set_color('blue')
ax.spines['left'].set_color('red')
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_color(None)
ax.spines['top'].set_color(None)
ax.plot([1,2,3,4,5])
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Setting limits

# %% [markdown]
# - Matplotlib automatically arrives at the minimum and maximum values of variables to be displayed along x, y axes of a plot
# - set the limits explicitly by using set_xlim() and set_ylim() functions

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,4))

x = np.arange(1,10)

ax[0].plot(x, np.exp(x))
ax[0].set_title('exp')

ax[1].plot(x, np.exp(x),'r')
ax[1].set_title('exp')
ax[1].set_ylim(0,10000)
ax[1].set_xlim(0,10)
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Setting Ticks and Tick Labels

# %% [markdown]
# - ticks are the markers denoting data points on axes
# - default tick locators and formatters are designed to be generally sufficient in many common situations
# - xticks() and yticks() function takes a list object as argument
# - this method will mark the data points at the given positions with ticks

# %%
import math

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,2))
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)

ax[0].plot(x, y)
ax[0].set_xlabel('angle')
ax[0].set_title('sine')
ax[0].set_yticks([-1,0,1])

ax[1].plot(x, y)
ax[1].set_xlabel('angle')
ax[1].set_title('sine')
ax[1].set_xticks([0,2,4,6])
ax[1].set_xticklabels(['zero','two','four','six'])
ax[1].set_yticks([-1,0,1])

plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Annotations

# %% [markdown]
# - graphical elements, often pieces of text, that explain, add context to, or otherwise highlight some portion of the visualized data

# %% [markdown]
# ### basic annotations

# %% [markdown]
# - two points to consider: the location of the data being annotated xy and the location of the annotation text xytext
# - both of these arguments are (x, y) tuple

# %%
fig, ax = plt.subplots(figsize=(3, 3))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.set_ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, autoscale_on=False, xlim=(-1, 5), ylim=(-3, 5))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s)

ax.annotate('figure pixels',
            xy=(10, 10), xycoords='figure pixels')

ax.annotate('figure points',
            xy=(80, 80), xycoords='figure points')

ax.annotate('point offset from data',
            xy=(2, 1), xycoords='data',
            xytext=(-15, 25), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='bottom')

ax.annotate('axes fraction',
            xy=(3, 1), xycoords='data',
            xytext=(0.8, 0.95), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top')

ax.annotate('figure fraction',
            xy=(.025, .975), xycoords='figure fraction',
            horizontalalignment='left', verticalalignment='top',
            fontsize=20)

# use negative points or pixels to specify from right, top -10, 10
# is 10 points to the left of the right side of the axes and 10
# points above the bottom
ax.annotate('pixel offset from axes fraction',
            xy=(1, 0), xycoords='axes fraction',
            xytext=(-20, 20), textcoords='offset pixels',
            horizontalalignment='right',
            verticalalignment='bottom')
# Out:
# Text(-20, 20, 'pixel offset from axes fraction')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
r = np.arange(0, 1, 0.001)
theta = 2*2*np.pi*r
line, = ax.plot(theta, r)

ind = 800
thisr, thistheta = r[ind], theta[ind]
ax.plot([thistheta], [thisr], 'o')
ax.annotate('a polar annotation',
            xy=(thistheta, thisr),  # theta, radius
            xytext=(0.05, 0.05),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left',
            verticalalignment='bottom')
# Out:
# Text(0.05, 0.05, 'a polar annotation')

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Plotting Examples

# %% [markdown]
# # Example 1: Histogram

# %% [markdown]
# - graphical representation of a frequency distribution of some numerical data
# - rectangles with equal width have heights with the associated frequencies

# %%
gaussian_numbers = np.random.normal(size=10000)
gaussian_numbers
# Out:
# array([ 0.33049708,  1.13140138, -0.75919118, ...,  1.76205194,
#        -0.68366554,  0.91980374])

# %%
plt.hist(gaussian_numbers)
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - returns a tuple of three objects (n, bins, patches)

# %%
n, bins, patches = plt.hist(gaussian_numbers)

# %% [markdown]
# - n contains the number of values of gaussian numbers that lie within the interval with the boundaries bins and bins [i + 1]

# %%
print("n: ", n, sum(n))
# Out:
# n:  [  10.   92.  543. 1743. 2767. 2728. 1534.  479.   94.   10.] 10000.0

# %% [markdown]
# - n is an array of frequencies
# - the last return value of hist is a list of patches, which corresponds to the rectangles with their properties

# %%
print("patches: ", patches)
for i in range(10):
    print(patches[i])
# Out:
# patches:  <BarContainer object of 10 artists>
# Rectangle(xy=(-3.76782, 0), width=0.756349, height=10, angle=0)
# Rectangle(xy=(-3.01148, 0), width=0.756349, height=92, angle=0)
# Rectangle(xy=(-2.25513, 0), width=0.756349, height=543, angle=0)
# Rectangle(xy=(-1.49878, 0), width=0.756349, height=1743, angle=0)
# Rectangle(xy=(-0.74243, 0), width=0.756349, height=2767, angle=0)
# Rectangle(xy=(0.0139181, 0), width=0.756349, height=2728, angle=0)
# Rectangle(xy=(0.770267, 0), width=0.756349, height=1534, angle=0)
# Rectangle(xy=(1.52662, 0), width=0.756349, height=479, angle=0)
# Rectangle(xy=(2.28296, 0), width=0.756349, height=94, angle=0)
# Rectangle(xy=(3.03931, 0), width=0.756349, height=10, angle=0)

# %% [markdown]
# ### changing number of bins

# %%
plt.hist(gaussian_numbers, bins=100)
plt.show()

# %%
plt.hist(gaussian_numbers, 
         bins=100, 
         orientation="horizontal")
plt.show()

# %% [markdown]
# ### density:
# - replaces the deprecated normed parameter
# - normalized to form a probability density, i. the area (or the integral) under the histogram makes the sum 1

# %%
n, bins, patches = plt.hist(gaussian_numbers, 
                            bins=100, 
                            density=True)
plt.show()
print("Area below the integral: ", np.sum(n * np.diff(bins)))
# Out:
# Area below the integral:  0.9999999999999999

# %% [markdown]
# ### edgecolor and color

# %%
plt.hist(gaussian_numbers, 
         bins=100, 
         density=True, 
         edgecolor="k",
         color="tab:orange")
plt.show()

# %% [markdown]
# ### cumulative histogram

# %%
plt.hist(gaussian_numbers, 
         bins=100, 
         stacked=True,
         cumulative=True,
         edgecolor='k')
plt.show()

# %% [markdown]
# ### combining two histograms with same number of bins (different dimensionality)

# %%
foo = np.random.normal(loc=1, size=100) # a normal distribution
bar = np.random.normal(loc=-1, size=10000) # a normal distribution

_, bins, _ = plt.hist(foo, bins=50, range=[-6, 6],density=True,edgecolor='k')
_ = plt.hist(bar, bins=bins, alpha=0.5,density=True,edgecolor='k')

# %% [markdown]
# ### combining histograms using numpy (same dimensionality)

# %%
# generate toy data
a=np.random.random(100)*0.5 #a uniform distribution
b=1-np.random.normal(size=100)*0.1 #a normal distribution 

# extract correct bins
bins=np.histogram(np.hstack((a,b)), bins=50)[1] #get the bin edges

# plotting
plt.hist(a, bins,edgecolor='k');
plt.hist(b, bins,alpha=0.5,edgecolor='k');

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Example 2: Scatter plot

# %% [markdown]
# - scatter() function plots one dot for each observation
# - two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### compare plots

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# ### set colors

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ### color each dot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ### set colormap and colorbar

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ### set size

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# ### set alpha

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# ### Combine Color Size and Alpha

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %% [markdown]
# ## Combining scatter plot and histograms

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Saving figures

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %% [markdown]
# ### save figure in different formats

# %%
figname = 'example_fancy_scatter_plot'
fig.patch.set_facecolor('white')
fig.savefig(figname+str('.png'), bbox_inches='tight', dpi=300, facecolor=fig.get_facecolor(), transparent=False)

# %%
fig.savefig(figname+str('.svg'), bbox_inches='tight', dpi=300, facecolor=fig.get_facecolor(), transparent=False)

# %%
fig.savefig(figname+str('.pdf'), bbox_inches='tight', dpi=300, facecolor=fig.get_facecolor(), transparent=False)

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Brief Introduction to Seaborn (using pandas)

# %% [markdown]
# ## Installation

# %%
# !pip install seaborn --upgrade
# Out:
# ...
#      -------------------------------------- 293.3/293.3 kB 2.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import libararies

# %%
import pandas
from matplotlib import pyplot as plt
import scipy
import seaborn as sns
import numpy as np

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ## Load dataset

# %%
df = sns.load_dataset('car_crashes')
print(df.head())
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ## using default Matplotlib plotting style vs. seaborn style

# %% [markdown]
# - set()/set_theme() function changes the global defaults for all plots using the matplotlib rcParams system

# %%
plt.scatter(df.speeding,df.alcohol)
plt.show()

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set()
plt.show()

# %% [markdown]
# ### remove top and right axis spines

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("ticks")
sns.despine()
plt.show()

# %% [markdown]
# - styles are customizable and can be customized by passing a dictionary of parameters to the set_style() function of Seaborn library

# %%
param=sns.axes_style()
param
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("dark")
sns.set_context("notebook")
plt.show()

# %% [markdown]
# ## Color Palette

# %%
sns.palplot(sns.color_palette("deep", 20))

# %%
sns.palplot(sns.color_palette("PiYG", 10))

# %% [markdown]
# # Plotting with Seaborn

# %% [markdown]
# ## load dataset

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="sex", col="day", col_wrap=2)

# %% [markdown]
# ## Histograms

# %% [markdown]
# ## load dataset

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.distplot(df['petal_length'],
             kde = False)
# Out:
# C:\Users\Dominic Gonschorek\AppData\Local\Temp\ipykernel_10392\2653885693.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'],
# <Axes: xlabel='petal_length'>

# %% [markdown]
# # Bar plot

# %%
# load dataset
titanic = sns.load_dataset('titanic')
# create plot
sns.barplot(x = 'embark_town',
            y = 'age', 
            data = titanic,
            palette = 'PuRd',
            errorbar=None 
            )
plt.show()

# %%
# create plot
sns.barplot(x = 'sex',
            y = 'survived', 
            hue = 'class', 
            data = titanic,
            palette = 'PuRd',
            order = ['male', 'female'],  
            capsize = 0.05,             
            saturation = 8,             
            errcolor = 'gray', 
            errwidth = 2,  
            errorbar = 'sd'  
            )
plt.legend()
plt.show()

# %% [markdown]
# # Count plot

# %%
# load dataset
titanic = sns.load_dataset('titanic')
# create plot
sns.countplot(x = 'class', 
              hue = 'who', 
              data = titanic, 
              palette = 'magma')
plt.title('Survivors')
plt.show()

# %% [markdown]
# # Joint plot

# %%
sns.set_style("dark")
tips=sns.load_dataset('tips')

sns.jointplot(x='total_bill', 
              y='tip',
              data=tips)

# %% [markdown]
# ### add regression line to scatter plot and kernel density estimate to histogram

# %%
sns.jointplot(x='total_bill', 
              y='tip', 
              data=tips, 
              kind='reg')

# %% [markdown]
# ### display kernel density estimate instead of scatter plot and histogram

# %%
sns.jointplot(x='total_bill', 
              y='tip', 
              data=tips, 
              kind='kde')

# %% [markdown]
# # KDE plot

# %% [markdown]
# - Kernel Density Estimate (KDE) that is used for visualizing the Probability Density of the continuous or non-parametric data variables

# %%
iris = sns.load_dataset("iris")
# Plotting the KDE Plot 
sns.kdeplot(iris.loc[(iris['species']=='setosa'), 
            'sepal_length'], 
            color='b', 
            fill=True, 
            label='setosa') 

sns.kdeplot(iris.loc[(iris['species']=='virginica'), 
            'sepal_length'], 
            color='r', 
            fill=True, 
            label='virginica')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# # Box plots

# %%
tips = sns.load_dataset("tips")
sns.boxplot(x="day", 
            y="total_bill", 
            data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin plots

# %%
tips = sns.load_dataset("tips")

fig,ax=plt.subplots(1,2,figsize=(10,3))

sns.violinplot(x="day", 
               y="total_bill", 
               hue="smoker",
               data=tips, 
               palette="muted",
               ax=ax[0])

sns.violinplot(x="day", 
               y="total_bill", 
               hue="smoker",
               data=tips, 
               palette="muted", 
               split=True,
               ax=ax[1])
ax[0].set_title('Normal')
ax[1].set_title('Groups splitted')
# Out:
# Text(0.5, 1.0, 'Groups splitted')

# %% [markdown]
# ## combining violin and swarm plot

# %%
tips = sns.load_dataset("tips")

fig,ax=plt.subplots(1,1,figsize=(5,3))

sns.violinplot(x="day", 
               y="total_bill", 
               data=tips, 
               palette="muted",
               ax=ax)

sns.swarmplot(x='day', 
              y='total_bill', 
              data=tips, 
              color='k', 
              alpha=0.7)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Heatmap

# %% [markdown]
# - two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colours

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
print(flights)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights,
            linewidths=.5,
            cmap="magma")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ### add respective values in the boxes

# %%
car_crashes = sns.load_dataset("car_crashes")
corr=car_crashes.corr()
print(corr)
sns.heatmap(corr,
            annot=True,
            linewidths=.5,
            cmap="magma")
# Out:
# C:\Users\Dominic Gonschorek\AppData\Local\Temp\ipykernel_10392\2539240016.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=car_crashes.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# ...

# %% [markdown]
# # Pair Plot

# %% [markdown]
# - simple way to visualize relationships between each variable

# %%
df = sns.load_dataset('iris')
sns.set_style("ticks")
sns.pairplot(df,
             hue = 'species',
             diag_kind = "kde",
             kind = "scatter",
             palette = "husl")
plt.show()
