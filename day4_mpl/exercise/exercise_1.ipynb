# %% [markdown]
# # Exercise 1: Notebook

# %% [markdown]
# - your exercise will be to reproduce the following plots without googling them specifically
# - if you run into the specific code, try not to use it as it won't help you to learn

# %% [markdown]
# # Exercises 1: Horizontal boxplot with observations (seaborn)

# %% [markdown]
# ### figure:

# %%
from IPython.display import Image
Image("/gpfs01/euler/User/dgonschorek/Github/python_course/day4_mpl/exercise_1_horizontal_boxplot.png")

# %% [markdown]
# ## import

# %%
# import libaries
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## load dataset

# %%
# load dataset
planets = sns.load_dataset("planets")

# %% [markdown]
# ## enter code here

# %%
# enter code here
